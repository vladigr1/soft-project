# %% [markdown]
# # Lab4 - compare between the algorithems

# %% [markdown]
# # StepWise

# %%
import algorithms

import warnings
warnings.filterwarnings("ignore") # ignore warning


in_threshold = 0.5
out_threshold = 0.05
sderived = 'quality of sleep'
data = algorithms.load_data('30days.csv', sderived)

lbasics = list(data.columns.values)
lbasics.remove(sderived)

amount_of_days = 15

# print(data_15_days)

from algorithms import stepwise_regression
import evaluation

(fit_model, param_in_model, cur_pvalue) = stepwise_regression(data, sderived, lbasics, in_threshold, out_threshold)
print(f'param_in_model: {param_in_model}')
print(f'cur_pvalue: {cur_pvalue}')
distance = evaluation.distance_vec(data, sderived, param_in_model, fit_model)
print(f'accuracy: {evaluation.accuracy(distance)}')

x, y = evaluation.evaluation_graph(data, sderived, lbasics, amount_of_days, stepwise_regression )
import numpy as np
import matplotlib.pyplot as plt


N = len(x)
c = range(N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c)
plt.xlabel("p-value")
plt.ylabel("accuracy")

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                loc="best", title="Model number")
ax.add_artist(legend1)
plt.title("Models produced by Stepwise regression")
plt.show()
# Out:
# param_in_model: ['mood', 'amount of sleep', 'physical activity', 'cognitive load', 'water']
# cur_pvalue: 0.2586072487902904
# accuracy: 0.7333333333333333

# %% [markdown]
# # Best-subset

# %%
import algorithms


in_threshold = 0.3
out_threshold = 0.05
sderived = 'quality of sleep'
data = algorithms.load_data('30days.csv', sderived)


lbasics = list(data.columns.values)
lbasics.remove(sderived)

amount_of_days = 15

# print(data_15_days)

from algorithms import best_subset
import evaluation

(fit_model, param_in_model, cur_pvalue) = best_subset(data, sderived, lbasics)
print(f'param_in_model: {param_in_model}')
print(f'cur_pvalue: {cur_pvalue}')
distance = evaluation.distance_vec(data, sderived, param_in_model, fit_model)
print(f'accuracy: {evaluation.accuracy(distance)}')

x, y = evaluation.evaluation_graph(data, sderived, lbasics, amount_of_days, best_subset )
import numpy as np
import matplotlib.pyplot as plt


N = len(x)
c = range(N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c)
plt.xlabel("p-value")
plt.ylabel("accuracy")

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                loc="best", title="Model number")
ax.add_artist(legend1)
plt.title("Models produced by Best subset")
plt.show()
# Out:
# param_in_model: ['cognitive load']
# cur_pvalue: 1.960969458769176e-06
# accuracy: 1.2

# %% [markdown]
# # Best-subset with spearman

# %%
import algorithms



sderived = 'quality of sleep'
data = algorithms.load_data('30days.csv', sderived)

lbasics = list(data.columns.values)
lbasics.remove(sderived)
amount_of_days = 15

# print(data_15_days)

from algorithms import best_subset_with_spearman, filter_lbasic_with_spearman
import evaluation


print(f'lbasic: {lbasics}')
precentage = 0.60
(lbasic_after_filter) = filter_lbasic_with_spearman(data, sderived, lbasics,precentage)
print(f'lbasic_after_filter: {lbasic_after_filter}')
(fit_model, param_in_model, cur_pvalue) = best_subset_with_spearman(data, sderived, lbasics,precentage)
print(f'param_in_model: {param_in_model}')
print(f'cur_pvalue: {cur_pvalue}')
distance = evaluation.distance_vec(data, sderived, param_in_model, fit_model)
print(f'accuracy: {evaluation.accuracy(distance)}')

x, y = evaluation.evaluation_graph(data, sderived, lbasics, amount_of_days, best_subset_with_spearman )
import numpy as np
import matplotlib.pyplot as plt


N = len(x)
c = range(N)

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c)
plt.xlabel("p-value")
plt.ylabel("accuracy")

# produce a legend with the unique colors from the scatter
legend1 = ax.legend(*scatter.legend_elements(),
                loc="best", title="Model number")
ax.add_artist(legend1)
plt.title("Models produced by best subset with Spearman correlation")
plt.show()
# Out:
# lbasic: ['mood', 'amount of sleep', 'physical activity', 'cognitive load', 'water']
# lbasic_after_filter: ['physical activity', 'water', 'amount of sleep']
# param_in_model: ['amount of sleep']
# cur_pvalue: 0.000912611985773278
# accuracy: 1.0
